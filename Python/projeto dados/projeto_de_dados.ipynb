# %%
import os
import pandas as pd
import plotly.express as px

lista_arquivo = os.listdir("/content/drive/MyDrive/coisas de python/Vendas")
display(lista_arquivo)

tabela_total = pd.DataFrame()

for arquivo in lista_arquivo:
  if "Vendas" in arquivo:
    tabela = pd.read_csv(f"/content/drive/MyDrive/coisas de python/Vendas/{arquivo}")
    tabela_total = tabela_total.append(tabela)

    display(tabela_total)
# Out:
# ['Vendas - Porto Alegre.csv',
#  'Vendas - Rio de Janeiro.csv',
#  'Vendas - Curitiba.csv',
#  'Vendas - São Paulo.csv',
#  'Devolucoes - Curitiba.csv',
#  'Devolucoes - Goiás.csv',
#  'Devolucoes - Salvador.csv',
#  'Vendas - Goiás.csv',
#  'Vendas - Salvador.csv',
#  'Devolucoes - Belo Horizonte.csv',
#  'Vendas - Fortaleza.csv',
#  'Devolucoes - Rio de Janeiro.csv',
#  'Vendas - Recife.csv',
#  'Devolucoes - São Paulo.csv',
#  'Vendas - Belo Horizonte.csv',
#  'Devolucoes - Fortaleza.csv',
#  'Devolucoes - Recife.csv',
#  'Devolucoes - Porto Alegre.csv']
#      Unnamed: 0     SKU    Produto  Quantidade Vendida Primeiro Nome  \
# 0            14  HL4379  Televisão                   4         Ylana
# 1            34  HL1148     Câmera                   1        Rubens
# 2            43  HL1148     Câmera                   5        Paloma
# 3            49  HL8851   Notebook                   5         Breno
# 4            52  HL4379  Televisão                   2        Lorena
# ...

# %% [markdown]
# # Nova seção

# %%
tabela_produtos = tabela_total.groupby('Produto').sum()
# .sum é usado para soma
# groupby é usado para agugar informações de tabelas
tabela_produtos = tabela_produtos[["Quantidade Vendida", "Preco Unitario"]].sort_values(by="Quantidade Vendida", ascending=False)
# é usado para a organização em ordem crescente e decrescente
# sendo True para crescente e False para decrescente
display(tabela_produtos)
# Out:
#             Quantidade Vendida  Preco Unitario
# Produto
# iPhone                    8974        15778100
# Televisão                 5931         4905000
# Notebook                  3249         3717000
# Android                   3183         3631200
# SmartWatch                2980         1393000
# Tablet                    2921         1556800
# Câmera                    2805         2020200

# %%
tabela_total['Faturamento'] = tabela_total['Quantidade Vendida'] * tabela_total['Preco Unitario']

tabela_faturamento = tabela_total.groupby('Produto').sum()
tabela_faturamento = tabela_faturamento[["Quantidade Vendida", "Preco Unitario", "Faturamento"]]
display(tabela_faturamento)
# Out:
#             Quantidade Vendida  Preco Unitario  Faturamento
# Produto
# Android                   3183         3631200     10822200
# Câmera                    2805         2020200      5890500
# Notebook                  3249         3717000     11371500
# SmartWatch                2980         1393000      4172000
# Tablet                    2921         1556800      4673600
# Televisão                 5931         4905000     14827500
# iPhone                    8974        15778100     47562200

# %%
tabela_lojas = tabela_total.groupby('Loja').sum()
tabela_lojas = tabela_lojas[['Faturamento']]
display(tabela_lojas)
# Out:
#                 Faturamento
# Loja
# Belo Horizonte      6480300
# Curitiba            7060500
# Fortaleza          14087900
# Goiás               7441800
# Porto Alegre        6868600
# Recife              7303000
# Rio de Janeiro     14867800
# Salvador           13111300
# São Paulo          22098300

# %%
grafico = px.bar(tabela_lojas, x= tabela_lojas.index, y='Faturamento')
grafico.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
